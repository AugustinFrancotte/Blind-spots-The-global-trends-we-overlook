# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
econ=pd.read_csv('datasets\Global Economy Indicators.csv')#,sep='|',encoding='cp1252'
col2=[]
# cleaning the names of the columns
for c in econ.columns:
    col2.append(c.strip())
econ.columns=col2
# cleaning the countries
for i, c in econ['Country'].items():
    econ.iloc[i,1]=c.strip()

# %%
prison=pd.read_csv("datasets\incarceration-rates-by-country-2025.csv")

# %%
coll=list(prison.columns)
coll[1]='Country'
prison.columns=coll

# %%
#data on freedom index, GNI per capita, GINI index,...
free=pd.read_csv('datasets\\freedom.csv')

# %%
#geographic data
geo=pd.read_csv('datasets\dimgeo.csv')

# %%
free2=pd.merge(free,geo,on='Country',how='inner')

# %%
free3=pd.merge(free2,prison,on='Country',how='inner')

# %%
free3
# Out:
#      Unnamed: 0  GNIPerCapita  GNIPerCapitaUSD CountryID  \
# 0             0        2390.0           8230.0       IND
# 1             1       12850.0          21250.0       CHN
# 2             2       76770.0          77950.0       USA
# 3             3        4580.0          14250.0       IDN
# 4             4        1560.0           6260.0       PAK
# ..          ...           ...              ...       ...
# 155         187        8430.0          13500.0       DMA
# 156         209           NaN              NaN       GNB
# 157         212           NaN              NaN       SVK
# 158         213           NaN              NaN       TLS
# 159         214           NaN              NaN       TWN
#
#      Imprisonment Rate (per 100K people)  Imprisonment      WB Income Group  \
# 0                                    NaN           NaN  Lower middle income
# 1                                    NaN           NaN  Upper middle income
# 2                                  531.0     1767200.0          High income
# 3                                    NaN           NaN  Upper middle income
# 4                                    NaN           NaN  Lower middle income
# ..                                   ...           ...                  ...
# 155                                348.0         261.0                  NaN
# 156                                  NaN           NaN           Low income
# 157                                  NaN           NaN          High income
# 158                                  NaN           NaN  Lower middle income
# 159                                  NaN           NaN          High income
#
#      GINI Index(WB)  GINI Index(UNU)        Country  ...  \
# 0              32.8            37.06          India  ...
# 1              35.7            36.67          China  ...
# 2              41.3            39.79  United States  ...
# 3              36.1            37.92      Indonesia  ...
# 4              29.6            29.59       Pakistan  ...
# ..              ...              ...            ...  ...
# 155             NaN              NaN       Dominica  ...
# 156            33.4            34.77  Guinea-Bissau  ...
# 157            24.1            24.12       Slovakia  ...
# 158            28.7            28.65    Timor-Leste  ...
# 159             NaN            32.58         Taiwan  ...
#
#      Geographical subregion                            Intermediary region  \
# 0             Southern Asia                                              —
# 1              Eastern Asia                                              —
# 2          Northern America                                  North America
# 3        South-eastern Asia                                              —
# 4             Southern Asia                                              —
# ..                      ...                                            ...
# 155               Caribbean  Latin America and the Caribbean North America
# 156          Western Africa                             Sub-Saharan Africa
# 157          Eastern Europe                                              —
# 158      South-eastern Asia                                              —
# 159            Eastern Asia                                              —
#
#     Continental region CountryCodeID flagCode  \
# 0                 Asia           IND       IN
# 1                 Asia           CHN       CN
# 2             Americas           USA       US
# 3                 Asia           IDN       ID
# 4                 Asia           PAK       PK
# ..                 ...           ...      ...
# 155           Americas           DMA       DM
# 156             Africa           GNB       GW
# 157             Europe           SVK       SK
# 158               Asia           TLS       TL
# 159               Asia           TWN       TW
#
#     IncarcerationRates_IncarcerationRatePer100k_rate_MultiYear  \
# 0                                                   41
# 1                                                  119
# 2                                                  541
# 3                                                   96
# 4                                                   45
# ..                                                 ...
# 155                                                356
# 156                                                 31
# 157                                                155
# 158                                                 55
# 159                                                252
#
#     IncarcerationRates_TotalIncarceratedPeople_num_MultiYear  \
# 0                                             573220.0
# 1                                            1690000.0
# 2                                            1808100.0
# 3                                             273697.0
# 4                                             108643.0
# ..                                                 ...
# 155                                              260.0
# 156                                              596.0
# 157                                             8385.0
# 158                                              763.0
# 159                                            59101.0
#
#      IncarcerationRates_FemalePctOfIncarcerated_pct_MultiYear  \
# 0                                                  4.1
# 1                                                  8.6
# 2                                                  8.8
# 3                                                  4.8
# 4                                                  1.6
# ..                                                 ...
# 155                                                1.2
# 156                                                2.6
# 157                                                7.3
# 158                                                4.1
# 159                                                9.6
#
#      IncarcerationRates_MalePctOfIncarcerated_pct_MultiYear  \
# 0                                                 95.9
# 1                                                 91.4
# 2                                                 91.2
# 3                                                 95.2
# 4                                                 98.4
# ..                                                 ...
# 155                                               98.8
# 156                                               97.4
# 157                                               92.7
# 158                                               95.9
# 159                                               90.4
#
#      IncarcerationRates_TotalIncarceratedDataYear_year_MultiYear
# 0                                               2022.0
# 1                                               2018.0
# 2                                               2022.0
# 3                                               2024.0
# 4                                               2024.0
# ..                                                 ...
# 155                                             2024.0
# 156                                             2017.0
# 157                                             2024.0
# 158                                             2021.0
# 159                                             2024.0
#
# [160 rows x 22 columns]

# %%
plt.figure(figsize=(15, 12))
sns.regplot(x="Freedom Idx/Gini Idx", y="IncarcerationRates_IncarcerationRatePer100k_rate_MultiYear", data=free3)
sns.scatterplot(data=free3, x='Freedom Idx/Gini Idx', y='IncarcerationRates_IncarcerationRatePer100k_rate_MultiYear',
                hue='WB Income Group', style='WB Income Group',s=100)



#sns.regplot(x="Freedom Idx/Gini Idx", y="Imprisonment Rate (per 100K people)", data=gini);
# Out:
# <Axes: xlabel='Freedom Idx/Gini Idx', ylabel='IncarcerationRates_IncarcerationRatePer100k_rate_MultiYear'>

# %%
plt.figure(figsize=(15, 12))
sns.regplot(x="Freedom Idx/Gini Idx", y="IncarcerationRates_IncarcerationRatePer100k_rate_MultiYear", data=free3)
sns.scatterplot(data=free3, x='Freedom Idx/Gini Idx', y='IncarcerationRates_IncarcerationRatePer100k_rate_MultiYear',
                hue='WB Income Group', style='WB Income Group',s=100)
plt.ylim(-40,700)



#sns.regplot(x="Freedom Idx/Gini Idx", y="Imprisonment Rate (per 100K people)", data=gini);
# Out:
# (-40.0, 700.0)

# %%
plt.figure(figsize=(15, 12))
ax = plt.gca()

sns.regplot(x="Freedom Idx/Gini Idx", y="IncarcerationRates_IncarcerationRatePer100k_rate_MultiYear", data=free3)
#ax.set_yscale('log')

sns.scatterplot(data=free3, x='Freedom Idx/Gini Idx', y='IncarcerationRates_IncarcerationRatePer100k_rate_MultiYear',
                hue='Continental region', style='Continental region',s=100)

#sns.regplot(x="Freedom Idx/Gini Idx", y="Imprisonment Rate (per 100K people)", data=gini);
# Out:
# <Axes: xlabel='Freedom Idx/Gini Idx', ylabel='IncarcerationRates_IncarcerationRatePer100k_rate_MultiYear'>

# %%
plt.figure(figsize=(15, 12))
ax = plt.gca()

sns.regplot(x="Freedom Idx/Gini Idx", y="IncarcerationRates_IncarcerationRatePer100k_rate_MultiYear", data=free3)
#ax.set_yscale('log')

sns.scatterplot(data=free3, x='Freedom Idx/Gini Idx', y='IncarcerationRates_IncarcerationRatePer100k_rate_MultiYear',
                hue='Continental region', style='Continental region',s=100)

#sns.regplot(x="Freedom Idx/Gini Idx", y="Imprisonment Rate (per 100K people)", data=gini);
plt.ylim(-40,700)
# Out:
# (-40.0, 700.0)
