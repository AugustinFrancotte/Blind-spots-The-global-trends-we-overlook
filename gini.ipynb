# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
econ=pd.read_csv('datasets\Global Economy Indicators.csv')#,sep='|',encoding='cp1252'
col2=[]
# cleaning the names of the columns
for c in econ.columns:
    col2.append(c.strip())
econ.columns=col2
# cleaning the countries
for i, c in econ['Country'].items():
    econ.iloc[i,1]=c.strip()

# %%
#data on freedom index, GNI per capita, GINI index, etc
gini=pd.read_csv('datasets\\freedom.csv')
gini
# Out:
#      Unnamed: 0  GniPerCapita  GniPerCapitaUSD CountryID flagCode  \
# 0             0        2390.0           8230.0       IND       IN
# 1             1       12850.0          21250.0       CHN       CN
# 2             2       76770.0          77950.0       USA       US
# 3             3        4580.0          14250.0       IDN       ID
# 4             4        1560.0           6260.0       PAK       PK
# ..          ...           ...              ...       ...      ...
# 220         220           NaN              NaN       TLS       TL
# 221         221           NaN              NaN       GNB       GW
# 222         222           NaN              NaN       PSE      NaN
# 223         223           NaN              NaN       XKX      NaN
# 224         224           NaN              NaN       PRK      NaN
#
#      IncarcerationRatePer100k  TotalIncarceratedPeople      WB income group  \
# 0                        41.0                 573220.0  Lower middle income
# ...

# %%
#geographic data
geo=pd.read_csv('datasets\dimgeo.csv')
geo
# Out:
#      Unnamed: 0                       Country Geographical subregion  \
# 0             0                       Algeria        Northern Africa
# 1             1                         Egypt        Northern Africa
# 2             2                         Libya        Northern Africa
# 3             3                       Morocco        Northern Africa
# 4             4                         Sudan        Northern Africa
# ..          ...                           ...                    ...
# 249         249                        Kosovo        Southern Europe
# 250         250          Yougoslavia (former)        Southern Europe
# 251         251                 USSR (former)         Eastern Europe
# 252         252  Netherland Antilles (former)              Caribbean
# 253         253                      Zanzibar         Eastern Africa
#
#                                Intermediary region Continental region  \
# ...

# %%
gini2=pd.merge(gini,geo,on='Country',how='inner')

# %%
gini2
# Out:
#      Unnamed: 0_x  GniPerCapita  GniPerCapitaUSD CountryID_x flagCode  \
# 0               0        2390.0           8230.0         IND       IN
# 1               1       12850.0          21250.0         CHN       CN
# 2               2       76770.0          77950.0         USA       US
# 3               3        4580.0          14250.0         IDN       ID
# 4               4        1560.0           6260.0         PAK       PK
# ..            ...           ...              ...         ...      ...
# 160           216           NaN              NaN         SVK       SK
# 161           220           NaN              NaN         TLS       TL
# 162           221           NaN              NaN         GNB       GW
# 163           223           NaN              NaN         XKX      NaN
# 164           224           NaN              NaN         PRK      NaN
#
#      IncarcerationRatePer100k  TotalIncarceratedPeople      WB income group  \
# ...

# %%
pays=['China','India','United States', 'France', 'Switzerland','Germany','Algeria','Morocco','Taiwan','Japan','Sweden','Denmark',
      'Malaysia','South Korea','Poland','Russia','Brazil','Argentina','Columbia','Chile','South Africa','Italy','Spain','Nigeria',
     'Cambodia','Thailand','Indonesia','Iran','Canada','Mexico','Singapour','Hong Kong','Taiwan','Egypt','Liberia','Angola',
     'Slovenia','Albania','Greece','Austria']

# %%
plt.figure(figsize=(15, 12))
sns.regplot(x="Freedom Idx/Gini Idx", y="GniPerCapitaUSD", data=gini2)
sns.scatterplot(data=gini2, x='Freedom Idx/Gini Idx', y='GniPerCapitaUSD',
                hue='Continental region', style='Continental region',s=100)

#plt.legend()
plt.ylim(-2000,122000)

for i, row in gini2.iterrows():
    if row['Country'] in pays:  # Annotation uniquement si le label n'est pas vide
        plt.text(row['Freedom Idx/Gini Idx'] + 0.01, row['GniPerCapitaUSD'], row['Country'], fontsize=12, color='black')
plt.savefig('graphs\\Gini-freedom-gnipercapita.png',bbox_inches='tight')
#but : ajouter le nom de quelques pays, et la région / sub région en couleurs
# Out:
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values

# %%
plt.figure(figsize=(15, 12))
sns.regplot(x="GINI_UNU", y="GniPerCapitaUSD", data=gini2)
sns.scatterplot(data=gini2, x='GINI_UNU', y='GniPerCapitaUSD',
                hue='Continental region', style='Continental region',s=100)

#plt.legend()
plt.ylim(-2000,122000)

for i, row in gini2.iterrows():
    if row['Country'] in pays:  # Annotation uniquement si le label n'est pas vide
        plt.text(row['GINI_UNU'] + 0.01, row['GniPerCapitaUSD'], row['Country'], fontsize=12, color='black')
plt.savefig('graphs\\Gini-gnipercapita.png',bbox_inches='tight')

#but : ajouter le nom de quelques pays, et la région / sub région en couleurs
# Out:
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values

# %%
plt.figure(figsize=(15, 12))
sns.regplot(x="Freedom Index", y="GniPerCapitaUSD", data=gini2)
sns.scatterplot(data=gini2, x='Freedom Index', y='GniPerCapitaUSD',
                hue='Continental region', style='Continental region',s=100)

#plt.legend()
plt.ylim(-2000,122000)

for i, row in gini2.iterrows():
    if row['Country'] in pays:  # Annotation uniquement si le label n'est pas vide
        plt.text(row['Freedom Index'] + 0.01, row['GniPerCapitaUSD'], row['Country'], fontsize=12, color='black')
plt.savefig('graphs\\freedom-gnipercapita.png',bbox_inches='tight')

#but : ajouter le nom de quelques pays, et la région / sub région en couleurs
# Out:
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
