# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
fact=pd.read_csv('datasets\fact_inf.csv')

# %%
fact
# Out:
#        Unnamed: 0 CountryID      Country  Year  AMA exchange rate  \
# 0               0       AFG  Afghanistan  1970           0.044998
# 1               1       AFG  Afghanistan  1971           0.044998
# 2               2       AFG  Afghanistan  1972           0.044998
# 3               3       AFG  Afghanistan  1973           0.044998
# 4               4       AFG  Afghanistan  1974           0.044998
# ...           ...       ...          ...   ...                ...
# 10234       10234       ZMB       Zambia  2017           9.519501
# 10235       10235       ZMB       Zambia  2018          10.458143
# 10236       10236       ZMB       Zambia  2019          12.889418
# 10237       10237       ZMB       Zambia  2020          18.344093
# 10238       10238       ZMB       Zambia  2021          20.018487
#
#        IMF based exchange rate  Population   Currency  Per capita GNI  \
# 0                     0.044998    10752971   Afghani              164
# ...

# %%
pop=fact.groupby(by=['Year'])['Population'].sum()

# %%
plt.plot(pop)
